# %%
import pandas as pd

# %%
import seaborn as sns

# %%
from sklearn import linear_model

# %%
data = pd.read_csv('SimpleLinearRegression.csv')

# %%
data
# Out:
#    diameter  price
# 0         8     10
# 1        10     13
# 2        12     16

# %%
sns.lmplot(x='diameter' , y= 'price', data = data)

# %%
reg = linear_model.LinearRegression()

# %%
reg.fit(data[['diameter']], data['price'])
# Out:
# LinearRegression()

# %%
reg.predict([[20]])
# Out:
# C:\Users\ksm58\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([28.])

# %%
reg.predict([[50]])
# Out:
# C:\Users\ksm58\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([73.])

# %%
reg.coef_
# Out:
# array([1.5])

# %%
reg.intercept_
# Out:
# -1.9999999999999982
